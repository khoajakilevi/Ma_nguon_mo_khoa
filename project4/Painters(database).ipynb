# %%
from pygments.formatters.html import webify
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd
import re
import sqlite3

# %%
# I.tao dataframe rong va noi chua link
all_links = []

# %%
# 0. Tạo cơ sở dữ liệu
conn = sqlite3.connect('painters.db')
c = conn.cursor()
try:
    c.execute('''
        CREATE TABLE painter (
            id integer primary key autoincrement,
            name text,
            birth text,
            death text,
            nationality text
        )
    ''')
except Exception as e:
    print(e)

# %%
def them(name, birth, death, nationality):
    conn = sqlite3.connect('painters.db')
    c = conn.cursor()
    # Them vao co so du lieu
    c.execute('''
        INSERT INTO painter(name, birth, death, nationality)
        VALUES (:name, :birth, :death, :nationality)
    ''',
      {
          'name': name,
          'birth': birth,
          'death': death,
          'nationality': nationality,
      })
    conn.commit()
    conn.close()

# %%
# II.lay tat ca duong dan de truy cap den painter
for i in range(65, 66):
    driver = webdriver.Chrome()
    url = "https://en.wikipedia.org/wiki/List_of_painters_by_name_beginning_with_%22"+chr(i)+"%22"
    #mo trang web
    driver.get(url)
    try:
        #doi khoang chung 3s
        time.sleep(3)
        #lay ra tat ca the ul
        ul_tags = driver.find_elements(By.TAG_NAME, "ul")
        print(len(ul_tags))
        #chon ul thu 21
        ul_painters = ul_tags[20] #dem tu 0
        #lay tat ca the <li> thuoc ul_painters
        li_tags = ul_painters.find_elements(By.TAG_NAME, "li")
        # #tao danh sach cac url
        links = [tag.find_element(By.TAG_NAME,"a").get_attribute("href") for tag in li_tags]
        for x in links:
            all_links.append(x)
        #tao danh sach cac title
        # titles = [tag.find_element(By.TAG_NAME,"a").get_attribute("title") for tag in li_tags]

        # #in ra danh sach
        # for link in links:
        #     print(link)

        #in ra danh sach
        # for title in titles:
        #     print(title)
    except:
        print("Error!!")
    #tat man hinh
    driver.quit()
# Out:
# 27

# %%
all_links
# Out:
# ['https://en.wikipedia.org/wiki/Herbert_Aach',
#  'https://en.wikipedia.org/wiki/Hans_von_Aachen',
#  'https://en.wikipedia.org/wiki/Pacita_Abad',
#  'https://en.wikipedia.org/wiki/Vilmos_Aba-Nov%C3%A1k',
#  'https://en.wikipedia.org/wiki/Riza_Abbasi',
#  'https://en.wikipedia.org/wiki/Niccol%C3%B2_dell%27Abbate',
#  'https://en.wikipedia.org/wiki/Giuseppe_Abbati',
#  'https://en.wikipedia.org/wiki/Salomon_van_Abb%C3%A9',
#  'https://en.wikipedia.org/wiki/Louise_Abb%C3%A9ma',
#  'https://en.wikipedia.org/wiki/Edwin_Austin_Abbey',
#  'https://en.wikipedia.org/wiki/Mary_Abbott_(artist)',
#  'https://en.wikipedia.org/wiki/Zeinab_Abd_al-Hamid',
#  'https://en.wikipedia.org/wiki/Basuki_Abdullah',
#  'https://en.wikipedia.org/wiki/Rowena_Meeks_Abdy',
#  'https://en.wikipedia.org/wiki/Josef_Abel',
#  'https://en.wikipedia.org/wiki/Evelyn_Abelson',
#  'https://en.wikipedia.org/wiki/Gertrude_Abercrombie',
#  'https://en.wikipedia.org/wiki/John_Brown_Abercromby',
#  'https://en.wikipedia.org/wiki/Johann_Ludwig_Aberli',
#  'https://en.wikipedia.org/wiki/Anna_Maria_Barbara_Abesch',
#  'https://en.wikipedia.org/wiki/Nikolaj_Abraham_Abildgaard',
#  'https://en.wikipedia.org/wiki/B%C3%A9la_Ap%C3%A1ti_Abkarovics',
#  'https://en.wikipedia.org/wiki/B%C3%A9la_Nagy_Abodi',
#  'https://en.wikipedia.org/wiki/Ruth_Abrahams',
#  'https://en.wikipedia.org/wiki/Herbert_Abrams',
#  'https://en.wikipedia.org/wiki/Ruth_Abrams_(artist)',
#  'https://en.wikipedia.org/wiki/Philip_Absolon',
#  'https://en.wikipedia.org/wiki/Otto_Abt',
#  'https://en.wikipedia.org/wiki/Ismail_Acar',
#  'https://en.wikipedia.org/wiki/Bernard_Accama',
#  'https://en.wikipedia.org/wiki/Andreas_Achenbach',
#  'https://en.wikipedia.org/wiki/Oswald_Achenbach',
#  'https://en.wikipedia.org/wiki/Patrick_Adam',
#  'https://en.wikipedia.org/wiki/Elinor_Proby_Adams',
#  'https://en.wikipedia.org/wiki/J._Ottis_Adams',
#  'https://en.wikipedia.org/wiki/John_Clayton_Adams',
#  'https://en.wikipedia.org/wiki/Pat_Adams',
#  'https://en.wikipedia.org/wiki/Robert_Adamson_(photographer)',
#  'https://en.wikipedia.org/wiki/Sarah_Gough_Adamson',
#  'https://en.wikipedia.org/wiki/Mary_Adshead',
#  'https://en.wikipedia.org/wiki/Jankel_Adler',
#  'https://en.wikipedia.org/wiki/M%C3%B3r_Adler',
#  'https://en.wikipedia.org/wiki/Willem_van_Aelst',
#  'https://en.wikipedia.org/wiki/Pieter_Aertsen',
#  'https://en.wikipedia.org/wiki/Nadir_Afonso',
#  'https://en.wikipedia.org/wiki/Yaacov_Agam',
#  'https://en.wikipedia.org/wiki/Jacques-Laurent_Agasse',
#  'https://en.wikipedia.org/wiki/Knud_Agger',
#  'https://en.wikipedia.org/wiki/Gyula_Aggh%C3%A1zy',
#  'https://en.wikipedia.org/wiki/Lubna_Agha',
#  'https://en.wikipedia.org/wiki/Christoph_Ludwig_Agricola',
#  'https://en.wikipedia.org/wiki/Ai_Xuan',
#  'https://en.wikipedia.org/wiki/John_Macdonald_Aiken',
#  'https://en.wikipedia.org/wiki/Aimitsu',
#  'https://en.wikipedia.org/wiki/Edgar_Ainsworth_(artist)',
#  'https://en.wikipedia.org/wiki/Ivan_Aivazovsky',
#  'https://en.wikipedia.org/wiki/Tadeusz_Ajdukiewicz',
#  'https://en.wikipedia.org/wiki/Ras_Akyem',
#  'https://en.wikipedia.org/wiki/Francesco_Albani',
#  'https://en.wikipedia.org/wiki/Josef_Albers',
#  'https://en.wikipedia.org/wiki/Mariotto_Albertinelli',
#  'https://en.wikipedia.org/wiki/Giocondo_Albertolli',
#  'https://en.wikipedia.org/wiki/Ivan_Albright',
#  'https://en.wikipedia.org/wiki/Kazimierz_Alchimowicz',
#  'https://en.wikipedia.org/wiki/Tivadar_Alconiere',
#  'https://en.wikipedia.org/wiki/Alfred_L._Copley',
#  'https://en.wikipedia.org/wiki/Eileen_Aldridge',
#  'https://en.wikipedia.org/wiki/Pierre_Alechinsky',
#  'https://en.wikipedia.org/wiki/George_Aleef',
#  'https://en.wikipedia.org/wiki/Fyodor_Alekseyev',
#  'https://en.wikipedia.org/wiki/Mikol%C3%A1%C5%A1_Ale%C5%A1',
#  'https://en.wikipedia.org/wiki/Cosmo_Alexander',
#  'https://en.wikipedia.org/wiki/John_Alexander_(painter)',
#  'https://en.wikipedia.org/wiki/Larry_D._Alexander',
#  'https://en.wikipedia.org/wiki/Lena_Alexander',
#  'https://en.wikipedia.org/wiki/Else_Alfelt',
#  'https://en.wikipedia.org/wiki/Brian_Alfred',
#  'https://en.wikipedia.org/wiki/Jessie_Algie',
#  'https://en.wikipedia.org/wiki/Andrew_Allan_(artist)',
#  'https://en.wikipedia.org/wiki/David_Allan_(painter)',
#  'https://en.wikipedia.org/wiki/Griselda_Allan',
#  'https://en.wikipedia.org/wiki/Robert_Weir_Allan',
#  'https://en.wikipedia.org/wiki/Rosemary_Allan',
#  'https://en.wikipedia.org/wiki/Daphne_Allen',
#  'https://en.wikipedia.org/wiki/Kathleen_Allen',
#  'https://en.wikipedia.org/wiki/Alessandro_Allori',
#  'https://en.wikipedia.org/wiki/Cristofano_Allori',
#  'https://en.wikipedia.org/wiki/Washington_Allston',
#  'https://en.wikipedia.org/wiki/Laura_Theresa_Alma-Tadema',
#  'https://en.wikipedia.org/wiki/Lawrence_Alma-Tadema',
#  'https://en.wikipedia.org/wiki/Almeida_J%C3%BAnior',
#  'https://en.wikipedia.org/wiki/Charles_Alston',
#  'https://en.wikipedia.org/wiki/Margareta_Alstr%C3%B6mer',
#  'https://en.wikipedia.org/wiki/Rudolf_von_Alt',
#  'https://en.wikipedia.org/wiki/Albrecht_Altdorfer',
#  'https://en.wikipedia.org/wiki/Altichiero',
#  'https://en.wikipedia.org/wiki/John_Altoon',
#  'https://en.wikipedia.org/wiki/Pedro_%C3%81lvarez_Castell%C3%B3',
#  'https://en.wikipedia.org/wiki/Edmond_Aman-Jean',
#  'https://en.wikipedia.org/wiki/Tarsila_do_Amaral',
#  'https://en.wikipedia.org/wiki/Christoph_Amberger',
#  'https://en.wikipedia.org/wiki/Friedrich_von_Amerling',
#  'https://en.wikipedia.org/wiki/Cuno_Amiet',
#  'https://en.wikipedia.org/wiki/Jacopo_Amigoni',
#  'https://en.wikipedia.org/wiki/Rodolfo_Amoedo',
#  'https://en.wikipedia.org/wiki/Rick_Amor',
#  'https://en.wikipedia.org/wiki/An_Gyeon',
#  'https://en.wikipedia.org/wiki/An_Zhengwen',
#  'https://en.wikipedia.org/wiki/Anna_Ancher',
#  'https://en.wikipedia.org/wiki/Michael_Ancher',
#  'https://en.wikipedia.org/wiki/Marion_Ancrum',
#  'https://en.wikipedia.org/wiki/Werner_Andermatt',
#  'https://en.wikipedia.org/wiki/Sophie_Gengembre_Anderson',
#  'https://en.wikipedia.org/wiki/Emma_Andijewska',
#  'https://en.wikipedia.org/wiki/Ion_Andreescu',
#  'https://en.wikipedia.org/wiki/Constantine_Andreou',
#  'https://en.wikipedia.org/wiki/Michael_Andrews_(artist)',
#  'https://en.wikipedia.org/wiki/Anthony_Angarola',
#  'https://en.wikipedia.org/wiki/Marie_Angel_(artist)',
#  'https://en.wikipedia.org/wiki/Fra_Angelico',
#  'https://en.wikipedia.org/wiki/Heinz_Anger',
#  'https://en.wikipedia.org/wiki/Hermenegildo_Anglada_Camarasa',
#  'https://en.wikipedia.org/wiki/Gaston_Anglade',
#  'https://en.wikipedia.org/wiki/Charles_Angrand',
#  'https://en.wikipedia.org/wiki/Sofonisba_Anguissola',
#  'https://en.wikipedia.org/wiki/Peggy_Angus',
#  'https://en.wikipedia.org/wiki/Rita_Angus',
#  'https://en.wikipedia.org/wiki/Albert_Anker',
#  'https://en.wikipedia.org/wiki/Margit_Anna',
#  'https://en.wikipedia.org/wiki/David_Annand',
#  'https://en.wikipedia.org/wiki/Louis_Anquetin',
#  'https://en.wikipedia.org/wiki/Pieter_van_Anraedt',
#  'https://en.wikipedia.org/wiki/Lizzy_Ansingh',
#  'https://en.wikipedia.org/wiki/Mary_Anne_Ansley',
#  'https://en.wikipedia.org/wiki/Horst_Antes',
#  'https://en.wikipedia.org/wiki/Cornelis_Anthonisz',
#  'https://en.wikipedia.org/wiki/Richard_Anuszkiewicz',
#  'https://en.wikipedia.org/wiki/Shigeru_Aoki',
#  'https://en.wikipedia.org/wiki/Chiho_Aoshima',
#  'https://en.wikipedia.org/wiki/Apelles',
#  'https://en.wikipedia.org/wiki/Zvest_Apollonio',
#  'https://en.wikipedia.org/wiki/Karel_Appel',
#  'https://en.wikipedia.org/wiki/Leonard_Appelbee',
#  'https://en.wikipedia.org/wiki/Joseph_Ignaz_Appiani',
#  'https://en.wikipedia.org/wiki/F%C3%A9lix_Ar%C3%A1uz',
#  'https://en.wikipedia.org/wiki/Janet_Archer',
#  'https://en.wikipedia.org/wiki/Giuseppe_Arcimboldo',
#  'https://en.wikipedia.org/wiki/Arent_Arentsz',
#  'https://en.wikipedia.org/wiki/Avigdor_Arikha',
#  'https://en.wikipedia.org/wiki/Abram_Arkhipov',
#  'https://en.wikipedia.org/wiki/Istv%C3%A1n_%C3%81rkossy',
#  'https://en.wikipedia.org/wiki/Edward_Armitage',
#  'https://en.wikipedia.org/wiki/John_Armleder',
#  'https://en.wikipedia.org/wiki/Hazel_Armour',
#  'https://en.wikipedia.org/wiki/John_Armstrong_(artist)',
#  'https://en.wikipedia.org/wiki/Georg_Arnold-Grabon%C3%A9',
#  'https://en.wikipedia.org/wiki/Jean_Arp',
#  'https://en.wikipedia.org/wiki/Eugenio_de_Arriba',
#  'https://en.wikipedia.org/wiki/Art_%26_Language',
#  'https://en.wikipedia.org/wiki/Richard_Artschwager',
#  'https://en.wikipedia.org/wiki/Asai_Ch%C5%AB',
#  'https://en.wikipedia.org/wiki/Pieter_Jansz_van_Asch',
#  'https://en.wikipedia.org/wiki/Pamela_Ascherson',
#  'https://en.wikipedia.org/wiki/%C3%81sgr%C3%ADmur_J%C3%B3nsson',
#  'https://en.wikipedia.org/wiki/Dennis_Ashbaugh',
#  'https://en.wikipedia.org/wiki/Gigad%C5%8D_Ashiyuki',
#  'https://en.wikipedia.org/wiki/Hans_Asper',
#  'https://en.wikipedia.org/wiki/Jan_Asselijn',
#  'https://en.wikipedia.org/wiki/Balthasar_van_der_Ast',
#  'https://en.wikipedia.org/wiki/Nikolai_Astrup',
#  'https://en.wikipedia.org/wiki/Jean-Michel_Atlan',
#  'https://en.wikipedia.org/wiki/Ren%C3%A9_Auberjonois_(painter)',
#  'https://en.wikipedia.org/wiki/%C3%89tienne_Aubry',
#  'https://en.wikipedia.org/wiki/Louis-Fran%C3%A7ois_Aubry',
#  'https://en.wikipedia.org/wiki/Mary_Audsley',
#  'https://en.wikipedia.org/wiki/John_James_Audubon',
#  'https://en.wikipedia.org/wiki/Frank_Auerbach',
#  'https://en.wikipedia.org/wiki/Jules_Robert_Auguste',
#  'https://en.wikipedia.org/wiki/Eric_Auld',
#  'https://en.wikipedia.org/wiki/George_Ault',
#  'https://en.wikipedia.org/wiki/Cassandra_Austen',
#  'https://en.wikipedia.org/wiki/Giuseppe_Avanzi',
#  'https://en.wikipedia.org/wiki/Edward_Avedisian',
#  'https://en.wikipedia.org/wiki/Hendrick_Avercamp',
#  'https://en.wikipedia.org/wiki/Milton_Avery',
#  'https://en.wikipedia.org/wiki/Ben_Avram',
#  'https://en.wikipedia.org/wiki/Nikola_Avramov',
#  'https://en.wikipedia.org/wiki/Awataguchi_Takamitsu',
#  'https://en.wikipedia.org/wiki/Joan_Ayling',
#  'https://en.wikipedia.org/wiki/Ay-O',
#  'https://en.wikipedia.org/wiki/Aya_Goda',
#  'https://en.wikipedia.org/wiki/Anton_A%C5%BEbe',
#  'https://en.wikipedia.org/wiki/Giovanni_Bernardino_Azzolini']

# %%
# III.Lay thong tin cua hoa si
count = 0
for link in all_links:
    if(count > 3):
        break
    count += 1

    print(link)
    try:
        #khoi tao webdriver
        driver = webdriver.Chrome()

        #mo trang
        url = link
        driver.get(url)

        #doi 2s
        time.sleep(2)

        #lay ten hoa si
        try:
            name = driver.find_element(By.TAG_NAME, "h1").text
        except:
            name = ""


        #lay ngay sinh hoa si
        try:
            birth_element = driver.find_element(By.XPATH, "//th[text()='Born']/following-sibling::td")
            birth = birth_element.text
            birth = re.findall(r'[0-9]{1,2}+\s+[A-Za-z]+\s+[0-9]{4}', birth)[0]
        except:
            birth = ""

        #lay ngay mat hoa si
        try:
            death_element = driver.find_element(By.XPATH, "//th[text()='Died']/following-sibling::td")
            death = death_element.text
            death = re.findall(r'[0-9]{1,2}+\s+[A-Za-z]+\s+[0-9]{4}', death)[0]
        except:
            death = ""

        #lay quoc tich hoa si
        try:
            nationality_element = driver.find_element(By.XPATH, "//th[text()='Nationality']/following-sibling::td")
            nationality = nationality_element.text
        except:
            nationality = ""

        # #tao dictionary thong tin hoa si
        # painter = {'name': name, 'birth': birth, 'death': death, 'nationality': nationality}
        # #chuyen doi dictionary thanh dataframe
        # painter_df = pd.DataFrame([painter])
        # #them thong tin vao df chinh
        # d = pd.concat([d, painter_df], ignore_index=True)
        # dong web
        # driver.quit()
        them(name, birth, death, nationality)

        # Dong web driver
        driver.quit()
    except Exception as e:
        print(e)
# Out:
# https://en.wikipedia.org/wiki/Herbert_Aach
# https://en.wikipedia.org/wiki/Hans_von_Aachen
# https://en.wikipedia.org/wiki/Pacita_Abad
# https://en.wikipedia.org/wiki/Vilmos_Aba-Nov%C3%A1k

# %%
# # IV.In thong tin ra file excel
# print(d)
# #dat ten file excel
# file_name = "Painters.xlsx"
# #saving the excel
# d.to_excel(file_name)
# print('DataFrame is written to Excel File successfully.')
